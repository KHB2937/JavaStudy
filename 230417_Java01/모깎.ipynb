# %% [markdown]
# <a href="https://colab.research.google.com/github/KHB2937/230417_Java01/blob/main/%EB%AA%A8%EA%B9%8E.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
df= pd.read_csv('/content/drive/MyDrive/dataset/NLP데이터셋/서울(동강용ver2).csv', encoding='utf-8', low_memory=False)
df
# Out:
#                          소재지전체주소         사업장명  업태구분명  \
# 0           서울 동대문구 경희대로 5 가동 2층   오레노카츠 경희대점     일식
# 1     서울 동대문구 경희대로1길 35 봄의정원 회기점     봄의정원 회기점     양식
# 2         서울 동대문구 회기로25길 23-5 1층         레알라면     라면
# 3            서울 동대문구 회기로23길 7 1층           옵소     한식
# 4        서울 동대문구 회기로21길 29 고깃집도훈        고깃집도훈     한식
# ...                          ...          ...    ...
# 8050            서울 용산구 후암로35길 37         후암맥주     기타
# 8051            서울 용산구 후암로34가길 4           또아     한식
# 8052          서울 용산구 한강대로104길 60  장삼봉마라탕엔마라샹궈  아시아음식
# 8053      서울 용산구 후암로16나길 26 혜당빌라      치키치킨24시     한식
# 8054            서울 용산구 두텁바위로 160  알찬밥집 용산도서관점     한식
#
#                                                  review   latitude  \
# 0     ['매장', '새로', '청결하다', '돈가스', '맛있다', '좋아요', '체다'...  37.592063
# 1     ['두번째', '방문', '입니다', '예약', '넓은', '자리', '안내', '...  37.591739
# 2     ['오렌지', '안', '맵', '주문', '오렌지', '맵', '주문', '너',...  37.591131
# 3     ['인테리어', '이쁘고', '매장', '청결하다', '좌석', '편해요', '곱창...  37.591185
# 4     ['역대', '급', '냉', '삼', '집', '발견', '듀록', '삼겹살', ...  37.592679
# ...                                                 ...        ...
# 8050  ['후', '암', '종점', '상호', '잘못', '후암동', '종점', '버스정...  37.549777
# 8051  ['백반', '인상', '적', '입니다', '제육', '볶음', '짱', '맛있다...  37.550774
# 8052  ['마라', '탕', '물질', '한번', '맛있다', '또', '방문', '밥',...  37.550161
# 8053  ['양도', '많고', '맛있다', '사장', '청결하다', '좋았습니다', '사실...  37.549441
# 8054  ['있었는데', '오늘', '계약', '만료', '네', '다른', '번창', '있...  37.552022
#
#        longitude  target  데이트  맛  서비스  청결
# 0     127.052165       1    1  1    1   1
# 1     127.050250       0    1  1    1   1
# 2     127.055390       1    0  1    1   1
# 3     127.053945       1    1  1    1   1
# 4     127.053131       0    0  1    1   1
# ...          ...     ...  ... ..  ...  ..
# 8050  126.976117       1    0  1    1   1
# 8051  126.977334       1    0  1    1   0
# 8052  126.975497       1    0  1    1   0
# 8053  126.978923       1    0  1    1   1
# 8054  126.980067       1    0  0    0   0
#
# [8055 rows x 11 columns]

# %%
import re

# Function to clean the text
def clean_text(text):
    # Remove special characters
    text = re.sub(r'\W', ' ', text)
    # Remove numbers
    text = re.sub(r'\d', ' ', text)
    # Remove single characters
    text = re.sub(r'\s+[a-zA-Z]\s+', ' ', text)
    # Substitute multiple spaces with a single space
    text = re.sub(r'\s+', ' ', text, flags=re.I)
    # Convert to lowercase
    text = text.lower()

    return text

# Apply the function to the 'review' column
df['review'] = df['review'].apply(clean_text)

df.head()
# Out:
#                       소재지전체주소        사업장명 업태구분명  \
# 0        서울 동대문구 경희대로 5 가동 2층  오레노카츠 경희대점    일식
# 1  서울 동대문구 경희대로1길 35 봄의정원 회기점    봄의정원 회기점    양식
# 2      서울 동대문구 회기로25길 23-5 1층        레알라면    라면
# 3         서울 동대문구 회기로23길 7 1층          옵소    한식
# 4     서울 동대문구 회기로21길 29 고깃집도훈       고깃집도훈    한식
#
#                                               review   latitude   longitude  \
# 0   매장 새로 청결하다 돈가스 맛있다 좋아요 체다 치즈 소스 제공 옵션 있어 좋구 회...  37.592063  127.052165
# 1   두번째 방문 입니다 예약 넓은 자리 안내 해 레드와인 차갑게 요구 하니 해주시 전...  37.591739  127.050250
# 2   오렌지 안 맵 주문 오렌지 맵 주문 너 어어 무 매워서 이틀 고생 두번째 방문 일...  37.591131  127.055390
# 3   인테리어 이쁘고 매장 청결하다 좌석 편해요 곱창 부위 설명 청결하다 기분 좋고 배...  37.591185  127.053945
# 4   역대 급 냉 삼 집 발견 듀록 삼겹살 가격 있는것도 감동 맛있다 백 선생님 특 제...  37.592679  127.053131
#
#    target  데이트  맛  서비스  청결
# 0       1    1  1    1   1
# 1       0    1  1    1   1
# 2       1    0  1    1   1
# 3       1    1  1    1   1
# 4       0    0  1    1   1

# %%
df.isnull().sum()

# %%
pip install gensim

# %%
# !pip install --upgrade tensorflow

# %%
# !pip install --upgrade keras

# %%
# !pip install --upgrade gensim

# %%
# !pip install --upgrade scikit-learn

# %%
# !pip3 uninstall -y tensorflow absl-py astunparse flatbuffers gast google-pasta grpcio h5py keras keras-preprocessing opt-einsum protobuf tensorboard tensorflow-io-gcs-filesystem termcolor tf-estimator-nightly wrapt

# %%
# !pip install tensorflow

# %%
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense, Embedding, LSTM
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from sklearn.model_selection import train_test_split
from gensim.models import Word2Vec
import numpy as np


# 최대 단어 사전 크기와 최대 문장 길이 설정
MAX_VOCAB_SIZE = 5000
MAX_SENTENCE_LENGTH = 900

# 타겟 레이블 정의
targets = ['데이트', '맛', '서비스', '청결']

# 토크나이저 객체 생성 및 텍스트를 시퀀스로 변환
tokenizer = Tokenizer(num_words=MAX_VOCAB_SIZE)
tokenizer.fit_on_texts(df['review'])
sequences = tokenizer.texts_to_sequences(df['review'])

# 시퀀스 패딩
X = pad_sequences(sequences, maxlen=MAX_SENTENCE_LENGTH)

# Word2Vec 모델 학습
sentences = [review.split() for review in df['review']]
word2vec = Word2Vec(sentences, vector_size=64, window=5, min_count=1, workers=4)

# 단어 사전의 모든 단어에 대해 word2vec 벡터를 가져옵니다.
embedding_matrix = np.zeros((MAX_VOCAB_SIZE, 64))
for word, i in tokenizer.word_index.items():
    if i < MAX_VOCAB_SIZE:
        if word in word2vec.wv:
            embedding_matrix[i] = word2vec.wv[word]

# LSTM 모델을 정의합니다.
inputs = Input(shape=(MAX_SENTENCE_LENGTH,))
x = Embedding(MAX_VOCAB_SIZE, 64, weights=[embedding_matrix], input_length=MAX_SENTENCE_LENGTH, trainable=False)(inputs)
x = LSTM(64, dropout=0.2, recurrent_dropout=0.2)(x)

# 각 타겟 레이블에 대한 출력 레이어를 정의합니다.
outputs = [Dense(1, activation='sigmoid')(x) for _ in targets]

# 다중 출력 모델을 정의합니다.
model = Model(inputs=inputs, outputs=outputs)

# 모델을 컴파일합니다.
model.compile(loss='binary_crossentropy', optimizer=Adam(), metrics=['accuracy'])

# 각 타겟 레이블에 대해 모델을 학습합니다.
y = [df[target].values for target in targets]
X_train, X_test = train_test_split(X, test_size=0.2, random_state=42)
y_train = [train_test_split(y_i, test_size=0.2, random_state=42)[0] for y_i in y]
y_test = [train_test_split(y_i, test_size=0.2, random_state=42)[1] for y_i in y]
model.fit(X_train, y_train, epochs=10, batch_size=32)
# Out:
# Epoch 1/10
# 202/202 [==============================] - 165s 795ms/step - loss: 1.2049 - dense_loss: 0.4912 - dense_1_loss: 0.0996 - dense_2_loss: 0.1748 - dense_3_loss: 0.4393 - dense_accuracy: 0.7719 - dense_1_accuracy: 0.9718 - dense_2_accuracy: 0.9524 - dense_3_accuracy: 0.8243
# Epoch 2/10
# 202/202 [==============================] - 160s 794ms/step - loss: 0.8190 - dense_loss: 0.3600 - dense_1_loss: 0.0430 - dense_2_loss: 0.1339 - dense_3_loss: 0.2821 - dense_accuracy: 0.8538 - dense_1_accuracy: 0.9876 - dense_2_accuracy: 0.9663 - dense_3_accuracy: 0.8901
# Epoch 3/10
# 202/202 [==============================] - 160s 790ms/step - loss: 0.5001 - dense_loss: 0.2514 - dense_1_loss: 0.0405 - dense_2_loss: 0.1284 - dense_3_loss: 0.0798 - dense_accuracy: 0.9103 - dense_1_accuracy: 0.9898 - dense_2_accuracy: 0.9691 - dense_3_accuracy: 0.9815
# Epoch 4/10
# 202/202 [==============================] - 166s 824ms/step - loss: 0.3915 - dense_loss: 0.2018 - dense_1_loss: 0.0357 - dense_2_loss: 0.1241 - dense_3_loss: 0.0299 - dense_accuracy: 0.9323 - dense_1_accuracy: 0.9899 - dense_2_accuracy: 0.9685 - dense_3_accuracy: 0.9941
# Epoch 5/10
# 202/202 [==============================] - 169s 836ms/step - loss: 0.3329 - dense_loss: 0.1815 - dense_1_loss: 0.0287 - dense_2_loss: 0.1119 - dense_3_loss: 0.0108 - dense_accuracy: 0.9359 - dense_1_accuracy: 0.9924 - dense_2_accuracy: 0.9704 - dense_3_accuracy: 0.9995
# Epoch 6/10
# 202/202 [==============================] - 169s 837ms/step - loss: 0.4215 - dense_loss: 0.1722 - dense_1_loss: 0.0248 - dense_2_loss: 0.1000 - dense_3_loss: 0.1244 - dense_accuracy: 0.9373 - dense_1_accuracy: 0.9941 - dense_2_accuracy: 0.9708 - dense_3_accuracy: 0.9600
# Epoch 7/10
# 202/202 [==============================] - 176s 871ms/step - loss: 0.4832 - dense_loss: 0.1832 - dense_1_loss: 0.0257 - dense_2_loss: 0.0962 - dense_3_loss: 0.1782 - dense_accuracy: 0.9337 - dense_1_accuracy: 0.9938 - dense_2_accuracy: 0.9711 - dense_3_accuracy: 0.9345
# Epoch 8/10
# 202/202 [==============================] - 176s 871ms/step - loss: 0.3110 - dense_loss: 0.1666 - dense_1_loss: 0.0185 - dense_2_loss: 0.0863 - dense_3_loss: 0.0396 - dense_accuracy: 0.9395 - dense_1_accuracy: 0.9952 - dense_2_accuracy: 0.9714 - dense_3_accuracy: 0.9978
# Epoch 9/10
# 202/202 [==============================] - 174s 860ms/step - loss: 0.2742 - dense_loss: 0.1579 - dense_1_loss: 0.0164 - dense_2_loss: 0.0840 - dense_3_loss: 0.0159 - dense_accuracy: 0.9440 - dense_1_accuracy: 0.9961 - dense_2_accuracy: 0.9732 - dense_3_accuracy: 0.9986
# Epoch 10/10
# 202/202 [==============================] - 175s 869ms/step - loss: 0.2517 - dense_loss: 0.1527 - dense_1_loss: 0.0127 - dense_2_loss: 0.0774 - dense_3_loss: 0.0090 - dense_accuracy: 0.9432 - dense_1_accuracy: 0.9975 - dense_2_accuracy: 0.9735 - dense_3_accuracy: 0.9994

# %%
# Save the model
model.save('다중출력모델ver3_model.keras')
